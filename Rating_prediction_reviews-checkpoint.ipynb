# %% [markdown]
# # Rating prediction

# %% [markdown]
# We have a client who has a website where people write different reviews for technical products. Now they are adding a new feature to their website i.e. The reviewer will have to add stars(rating) as well with the review. The rating is out 5 stars and it only has 5 options available 1 star, 2 stars, 3 stars, 4 stars, 5 stars. Now they want to predict ratings for the reviews which were written in the past and they don’t have a rating. So, we have to build an application which can predict the rating by seeing the review.

# %%
import selenium
from selenium import webdriver

# %%
#importing webdriver
driver=webdriver.Chrome(r"C:\Users\Sumukh\Appdata\Local\Temp\Temp1_chromedriver_win32.zip\chromedriver.exe")

# %%
#getting the website to scrape
driver.get("https://www.amazon.in/HP-Processor-14-inch-Windows-14s-dq2535TU/dp/B0928NL6F3/ref=sr_1_1_sspa?dchild=1&keywords=laptop&qid=1624083218&sr=8-1-spons&psc=1&spLa=ZW5jcnlwdGVkUXVhbGlmaWVyPUExUFBTN1RKNDJRVE5QJmVuY3J5cHRlZElkPUEwMTg3MDU4MVJKTU0xSTEzTURaNyZlbmNyeXB0ZWRBZElkPUEwMTI1MDMwMkQ4QUtCQ0gwVVMyOCZ3aWRnZXROYW1lPXNwX2F0ZiZhY3Rpb249Y2xpY2tSZWRpcmVjdCZkb05vdExvZ0NsaWNrPXRydWU=")

# %%
#collecting the required information into empty box
Reviews=[]
Rating=[]
for i in range(0,500):#setting the range
    for j in driver.find_elements_by_xpath("//div[@class='a-expander-content reviewText review-text-content a-expander-partial-collapse-content']/span"):
        Reviews.append(j.text)#getting the review of the laptop
    for k in driver.find_elements_by_xpath("//span[@class='a-size-medium a-color-base']"):
        Rating.append(k.text)#getting the ratings of the laptop

# %%
#loding the review
Reviews
# Out:
# ['Super awesome laptop....runs smoothly ...valorant runs on it like fluid...just amazing',
#  'I\'m using this for past 1 week without any issues. Overall product is good with smooth performance, good resolution, pre-installed MS products etc. Could have been better with backlit keyboard, finger sensor & camera cover option which is available in 15" inch variant.',
#  'Light weight,smooth to work , processing is better',
#  "It says Full HD screen and they delivered with a HD Ready screen.\n\nMy mistake is that I didn't search for the model no and check on hp website.",
#  'Truly disappointed with HP . Its a corei5 11th gen laptop, which heats up like old amd laptops. I urge everyone not to go for this one. HP need to think and change this model. Thanks to Amazon for accepting the return',
# ...

# %%
#loading the rating
Rating
# Out:
# ['4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4 out of 5',
# ...

# %%
#scraping the website using webchrome driver
driver.get("https://www.amazon.in/TECNO-Spark-Storage-Battery-Camera/dp/B096LS7N6Z/ref=sr_1_1_sspa?dchild=1&keywords=mobile&qid=1624172996&sr=8-1-spons&psc=1&spLa=ZW5jcnlwdGVkUXVhbGlmaWVyPUEzSFkyUExUTENJWDMyJmVuY3J5cHRlZElkPUEwNzQ5NDExMzFTS0YzOEtWMVpQVSZlbmNyeXB0ZWRBZElkPUEwMzAwNDI2MVBaU1NBSjlLUkFLMCZ3aWRnZXROYW1lPXNwX2F0ZiZhY3Rpb249Y2xpY2tSZWRpcmVjdCZkb05vdExvZ0NsaWNrPXRydWU=")

# %%
review=[]
rating=[]
for m in range(0,500):#setting the range
    for a in driver.find_elements_by_xpath("//div[@class='a-expander-content reviewText review-text-content a-expander-partial-collapse-content']/span"):
         review.append(a.text)#scrapping the mobile review
    for l in driver.find_elements_by_xpath("//span[@class='a-size-medium a-color-base']"):
        rating.append(l.text)#scraping the mobile rating

# %%
#loding the review
review
# Out:
# ['Charger and speaker 🤷',
#  'Good..but no music player!!! Lots of app.',
#  'Good',
#  'Tecno good phone camera processar also all of best in mobile only buy 7250 good prise thanks Amazon',
#  'Charger and speaker 🤷',
#  'Good..but no music player!!! Lots of app.',
#  'Good',
#  'Tecno good phone camera processar also all of best in mobile only buy 7250 good prise thanks Amazon',
#  'Charger and speaker 🤷',
#  'Good..but no music player!!! Lots of app.',
#  'Good',
#  'Tecno good phone camera processar also all of best in mobile only buy 7250 good prise thanks Amazon',
#  'Charger and speaker 🤷',
#  'Good..but no music player!!! Lots of app.',
#  'Good',
#  'Tecno good phone camera processar also all of best in mobile only buy 7250 good prise thanks Amazon',
#  'Charger and speaker 🤷',
#  'Good..but no music player!!! Lots of app.',
#  'Good',
#  'Tecno good phone camera processar also all of best in mobile only buy 7250 good prise thanks Amazon',
#  'Charger and speaker 🤷',
# ...

# %%
#loading the rating
rating
# Out:
# ['5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
#  '5 out of 5',
# ...

# %%
#Getting the webscraping site of the product
driver.get("https://www.amazon.in/Boult-Audio-Bluetooth-Headphones-Cancellation/dp/B088YKSNTX/ref=sr_1_2_sspa?dchild=1&keywords=headphones&qid=1624173904&smid=A14CZOWI0VEHLG&sr=8-2-spons&psc=1&spLa=ZW5jcnlwdGVkUXVhbGlmaWVyPUEyUDVFNVYwUVQ1S0NXJmVuY3J5cHRlZElkPUEwNTk5MDcxM0pGOFhUQktMQ0pWUCZlbmNyeXB0ZWRBZElkPUEwNjc0NTQ2M1JQMkxLRFdCNkZZVSZ3aWRnZXROYW1lPXNwX2F0ZiZhY3Rpb249Y2xpY2tSZWRpcmVjdCZkb05vdExvZ0NsaWNrPXRydWU=")

# %%
rewev=[]#collecting the information empty box
rati=[]
for s in range(0,500):#setting the range
    for t in driver.find_elements_by_xpath("//div[@class='a-expander-content reviewText review-text-content a-expander-partial-collapse-content']/span"):
        rewev.append(t.text)#collecting the reviews of headphone
    for e in driver.find_elements_by_xpath("//span[@class='a-size-medium a-color-base']"):
        rati.append(e.text)#collecting the rating of headphone

# %%
rewev
# Out:
# ['They are really a beast . Vocals are crisp even at high bass is just above average but give a nice feel and are super comfortable at this price point these are the best',
#  'According to price product is more good by my exceptation... happy to buy full money saver and awesome product.... happy to buy from Amazon...I have a best shopping experience here....gud service and delivery on time...#happy with boult',
#  'Super Bass... Sounds quality is good .. Rich feel.. Awesome looks',
# ...

# %%
rati
# Out:
# ['3.8 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
#  '3.8 out of 5',
# ...

# %%
#Getting the webscrapping site of the product
driver.get("https://www.amazon.in/GOQii-temperature-pressure-personal-Coaching/dp/B0877MB5HN/ref=sr_1_1_sspa?crid=2YX96Q4GC8ERD&dchild=1&keywords=smartwatch&qid=1624181733&smid=AT95IG9ONZD7S&sprefix=smartwa%2Caps%2C648&sr=8-1-spons&psc=1&spLa=ZW5jcnlwdGVkUXVhbGlmaWVyPUEyRUE2RjFPMjdSRkM1JmVuY3J5cHRlZElkPUEwMTAxNDg0MkM2TllDTzBCOTBCVCZlbmNyeXB0ZWRBZElkPUEwODkwMTk1MTNaRlU0QllJQzBZVCZ3aWRnZXROYW1lPXNwX2F0ZiZhY3Rpb249Y2xpY2tSZWRpcmVjdCZkb05vdExvZ0NsaWNrPXRydWU=")

# %%
rev=[]#storing the revew in the empty box
rat=[]#storing the rating in the empty box
for q in range(0,500):#setting the range
    for w in driver.find_elements_by_xpath("//div[@class='a-expander-content reviewText review-text-content a-expander-partial-collapse-content']/span"):
        rev.append(w.text)#collecting the review of the smart watch
    for d in driver.find_elements_by_xpath("//span[@class='a-size-medium a-color-base']"):
        rat.append(d.text)#collecting the rating of the rating

# %%
rev
# Out:
# ["Initial Review after 2 days of usage;\n\nHeart Rate and Steps are accurate.\nTemperature, Sleep and SpO2 measurements are also good. However...\nBP measurement is a complete failure... It's has 4 categories to choose from... Low, Normal, High and Very High... The readings are just based on the category you choose and has nothing to do with the actual condition or reading.. Quite disappointed... Hope this is corrected in future updates..\n\nOverall, kind of a good product... Please don't buy it if you are specifically looking to use it to measure your BP. Thanks!",
#  'BP Measurement is way different from a standard clinical measurement hence depending on it can be counter productive. It is just a glorified pedometer with OLED display.Not worth buying paying so much when pedometers with OLED can be got much cheaper.',
# ...

# %%
rat
# Out:
# ['3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
# ...

# %%
#now i will store all the reviws and rating in dataframe
#importing required libraries
import pandas as pd
import numpy as np

# %%
#storing the all the data in reviews
Reviews=np.concatenate([Reviews,review,rewev,rev])

# %%
Reviews
# Out:
# array(['Super awesome laptop....runs smoothly ...valorant runs on it like fluid...just amazing',
#        'I\'m using this for past 1 week without any issues. Overall product is good with smooth performance, good resolution, pre-installed MS products etc. Could have been better with backlit keyboard, finger sensor & camera cover option which is available in 15" inch variant.',
#        'Light weight,smooth to work , processing is better', ...,
# ...

# %%
rev=pd.DataFrame({"Reviews":Reviews})

# %%
rev
# Out:
#                                                  Reviews
# 0      Super awesome laptop....runs smoothly ...valor...
# 1      I'm using this for past 1 week without any iss...
# 2      Light weight,smooth to work , processing is be...
# 3      It says Full HD screen and they delivered with...
# 4      Truly disappointed with HP . Its a corei5 11th...
# ...                                                  ...
# 13996  I have been using samsung S2 and then honor ma...
# 13997  I am writing the review after 3 day use...\nPR...
# 13998  I am very much disappointed from this product....
# 13999  After reading Bachchan Sir’s blog , I couldn’t...
# 14000  This is a second time I’m buying a GOQii produ...
#
# [14001 rows x 1 columns]

# %%
rev.to_csv('revies_description.csv',index=False)

# %%
Rating=np.concatenate([Rating,rating,rati,rat])

# %%
Rating
# Out:
# array(['4 out of 5', '4 out of 5', '4 out of 5', ..., '3.9 out of 5',
#        '3.9 out of 5', '3.9 out of 5'], dtype='<U12')

# %%
len(Rating)
# Out:
# 2000

# %%
#importing all the data in pandas 
df=pd.DataFrame({"Reviews":Reviews[:2000],"Ratings":Rating[:2000]})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-130-9ae95471fe97> in <module>
#       1 #importing all the data in pandas
# ----> 2 df=pd.DataFrame({"Reviews":Reviews[:2000],"Ratings":Rating[:2000]})
#
# TypeError: 'map' object is not subscriptable

# %%
df
# Out:
#                                                 Reviews       Ratings
# 0     Super awesome laptop....runs smoothly ...valor...    4 out of 5
# 1     I'm using this for past 1 week without any iss...    4 out of 5
# 2     Light weight,smooth to work , processing is be...    4 out of 5
# 3     It says Full HD screen and they delivered with...    4 out of 5
# 4     Truly disappointed with HP . Its a corei5 11th...    4 out of 5
# ...                                                 ...           ...
# 1995  It says Full HD screen and they delivered with...  3.9 out of 5
# 1996  Truly disappointed with HP . Its a corei5 11th...  3.9 out of 5
# 1997  Worst ever product i got it... They mentioned ...  3.9 out of 5
# 1998   Awesome laptop\nGood for engineering students...  3.9 out of 5
# 1999  Very good product. After switching on it gets ...  3.9 out of 5
#
# [2000 rows x 2 columns]

# %%
df.to_csv("rating_prediction.csv",index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-ae789d9966eb> in <module>
# ----> 1 df.to_csv("rating_prediction.csv",index=False)
#
# NameError: name 'df' is not defined

# %%
df=pd.read_csv("rating_prediction.csv")

# %%
df
# Out:
#                                                 Reviews       Ratings
# 0     Super awesome laptop....runs smoothly ...valor...    4 out of 5
# 1     I'm using this for past 1 week without any iss...    4 out of 5
# 2     Light weight,smooth to work , processing is be...    4 out of 5
# 3     It says Full HD screen and they delivered with...    4 out of 5
# 4     Truly disappointed with HP . Its a corei5 11th...    4 out of 5
# ...                                                 ...           ...
# 1995  It says Full HD screen and they delivered with...  3.9 out of 5
# 1996  Truly disappointed with HP . Its a corei5 11th...  3.9 out of 5
# 1997  Worst ever product i got it... They mentioned ...  3.9 out of 5
# 1998   Awesome laptop\nGood for engineering students...  3.9 out of 5
# 1999  Very good product. After switching on it gets ...  3.9 out of 5
#
# [2000 rows x 2 columns]

# %% [markdown]
# For rating prediction by seeing the review, i collected reviews and rating of different product from the amazon site.Now i will proceed to perform NLP.

# %%
rating=pd.read_csv("rating_prediction.csv")

# %%
#Importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
import re

# %%
#Uploading the dataset
rating
# Out:
#                                                 Reviews       Ratings
# 0     Super awesome laptop....runs smoothly ...valor...    4 out of 5
# 1     I'm using this for past 1 week without any iss...    4 out of 5
# 2     Light weight,smooth to work , processing is be...    4 out of 5
# 3     It says Full HD screen and they delivered with...    4 out of 5
# 4     Truly disappointed with HP . Its a corei5 11th...    4 out of 5
# ...                                                 ...           ...
# 1995  It says Full HD screen and they delivered with...  3.9 out of 5
# 1996  Truly disappointed with HP . Its a corei5 11th...  3.9 out of 5
# 1997  Worst ever product i got it... They mentioned ...  3.9 out of 5
# 1998   Awesome laptop\nGood for engineering students...  3.9 out of 5
# 1999  Very good product. After switching on it gets ...  3.9 out of 5
#
# [2000 rows x 2 columns]

# %%
#checking the shape
print("shape:",rating.shape)
# Out:
# shape: (2000, 2)

# %%
#There is two thousand rows and 2 columns

# %%
#ratio
print("review ratio:",round(len(rating[rating["Reviews"]=="review"])/len(rating.Reviews),2)*100,"%")
print("rating ratio:",round(len(rating[rating["Ratings"]=="rating"])/len(rating.Ratings),2)*100,"%")
# Out:
# review ratio: 0.0 %
# rating ratio: 0.0 %

# %%
#checking the value counts
rating.Reviews.value_counts()
# Out:
# Very good product. After switching on it gets ready to use in less than 10 seconds and gets switch off in less than 5 seconds. Using multiple tabs at a time does not make anything slow. Heavy word, excel and PowerPoint usage is also smooth. Product is recent launch in 2021 and very useful in working from home or for online tasks. Best value for money. I exchanged by Dell laptop which was i3 and 4gb ram and was very slow. For any decent use the minimum requirement is i5 with 8gb ram and in this product the SSD, turbo boost and graphics card makes it much faster. Full HD resolution gives super picture quality.    250
# ...

# %%
#Checking the value_counts of rating
rating.Ratings.value_counts()
# Out:
# 4 out of 5      500
# 3.8 out of 5    500
# 3.9 out of 5    500
# 5 out of 5      500
# Name: Ratings, dtype: int64

# %%
#converted the rating into number
rating.replace({"4 out of 5":4,"3.8 out of 5":3,"5 out of 5" :5,"3.9 out of 5":4},inplace=True)

# %%
rating
# Out:
#                                                 Reviews  Ratings
# 0     Super awesome laptop....runs smoothly ...valor...        4
# 1     I'm using this for past 1 week without any iss...        4
# 2     Light weight,smooth to work , processing is be...        4
# 3     It says Full HD screen and they delivered with...        4
# 4     Truly disappointed with HP . Its a corei5 11th...        4
# ...                                                 ...      ...
# 1995  It says Full HD screen and they delivered with...        4
# 1996  Truly disappointed with HP . Its a corei5 11th...        4
# 1997  Worst ever product i got it... They mentioned ...        4
# 1998   Awesome laptop\nGood for engineering students...        4
# 1999  Very good product. After switching on it gets ...        4
#
# [2000 rows x 2 columns]

# %% [markdown]
# # Applying Natural Processing Language

# %% [markdown]
# # clean data

# %%
#Covert the review at lower case
rating['Reviews']=rating['Reviews'].str.lower()
#replace number with number
rating["Reviews"]=rating["Reviews"].str.replace(r'\d+(\.\d+)?',' ')
#Remove all chracter not in english alphabet
rating['Reviews']=rating['Reviews'].str.replace(r'[^a-zA-Z]',' ' )

# %%
#Remove Punchuation
rating['Reviews']=rating['Reviews'].str.replace(r'[^\w\d\s]',' ')
#Replace whitespace between terms with a single space
rating['Reviews']=rating['Reviews'].str.replace(r'\s+',' ')
#Remove leading and trailing whitespace
rating['Reviews']=rating['Reviews'].str.replace(r'^\s+|\s+?$', '')

# %%
rating
# Out:
#                                                 Reviews  Ratings
# 0     super awesome laptop runs smoothly valorant ru...        4
# 1     i m using this for past week without any issue...        4
# 2      light weight smooth to work processing is better        4
# 3     it says full hd screen and they delivered with...        4
# 4     truly disappointed with hp its a corei th gen ...        4
# ...                                                 ...      ...
# 1995  it says full hd screen and they delivered with...        4
# 1996  truly disappointed with hp its a corei th gen ...        4
# 1997  worst ever product i got it they mentioned pro...        4
# 1998  awesome laptop good for engineering students w...        4
# 1999  very good product after switching on it gets r...        4
#
# [2000 rows x 2 columns]

# %% [markdown]
# # Explore Data

# %%
#Create and print rating distribution graph 
rating_plot=rating.groupby(["Ratings"]).count().plot(kind="bar",legend=None,title='Rating Distribution')
plt.xlabel('Ratings')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
rating
# Out:
#                                                 Reviews  Ratings
# 0     super awesome laptop runs smoothly valorant ru...        4
# 1     i m using this for past week without any issue...        4
# 2      light weight smooth to work processing is better        4
# 3     it says full hd screen and they delivered with...        4
# 4     truly disappointed with hp its a corei th gen ...        4
# ...                                                 ...      ...
# 1995  it says full hd screen and they delivered with...        4
# 1996  truly disappointed with hp its a corei th gen ...        4
# 1997  worst ever product i got it they mentioned pro...        4
# 1998  awesome laptop good for engineering students w...        4
# 1999  very good product after switching on it gets r...        4
#
# [2000 rows x 2 columns]

# %%
#import libratries
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import cross_val_score,GridSearchCV
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.linear_model import LogisticRegression,SGDClassifier
from sklearn.naive_bayes import MultinomialNB
from wordcloud import STOPWORDS,WordCloud
from sklearn.model_selection import train_test_split
import string
import nltk
from nltk.corpus import stopwords
from sklearn.svm import SVC

# %%
#Remove stopwords
stop_words=set(stopwords.words('english')+["u","O","ur","4","2","in","dont","remove"])
rating["Reviews"]=rating["Reviews"].apply(lambda x:' '.join(
          term for term in x.split() if term not in stop_words))

# %%
rating
# Out:
#                                                 Reviews  Ratings
# 0     super awesome laptop runs smoothly valorant ru...        4
# 1     using past week without issues overall product...        4
# 2            light weight smooth work processing better        4
# 3     says full hd screen delivered hd ready screen ...        4
# 4     truly disappointed hp corei th gen laptop heat...        4
# ...                                                 ...      ...
# 1995  says full hd screen delivered hd ready screen ...        4
# 1996  truly disappointed hp corei th gen laptop heat...        4
# 1997  worst ever product got mentioned processer ghz...        4
# 1998  awesome laptop good engineering students bough...        4
# 1999  good product switching gets ready use less sec...        4
#
# [2000 rows x 2 columns]

# %% [markdown]
# # Splitting the data into train_test_split

# %%
#spliting the feature
vectorizer=TfidfVectorizer()
rating_feature=vectorizer.fit_transform(rating['Reviews'])
x=rating_feature
y=rating['Ratings']

# %%
#checking the shape
x.shape
# Out:
# (2000, 153)

# %%
#checking the shape
y.shape
# Out:
# (2000,)

# %%
#spliting the data
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.4,random_state=22,stratify=y)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1200, 153)
# (800, 153)
# (1200,)
# (800,)

# %% [markdown]
# # LogisticRegression

# %%
lg=LogisticRegression()
lg.fit(x_train,y_train)
predy=lg.predict(x_test)
print("Accuracy_score:",  accuracy_score(y_test,predy))
print("Classification_report:",   classification_report(y_test,predy))
print("confusion_matrix:",   confusion_matrix(y_test,predy))
# Out:
# Accuracy_score: 0.5
# Classification_report:               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00       200
#            4       0.50      1.00      0.67       400
#            5       0.00      0.00      0.00       200
#
#     accuracy                           0.50       800
#    macro avg       0.17      0.33      0.22       800
# weighted avg       0.25      0.50      0.33       800
#
# confusion_matrix: [[  0 200   0]
#  [  0 400   0]
#  [  0 200   0]]

# %%
clf_benchmark = LogisticRegression(random_state=22).fit(x_train, y_train)
print( classification_report(y_test, clf_benchmark.predict(x_test), digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            3     0.0000    0.0000    0.0000       200
#            4     0.5000    1.0000    0.6667       400
#            5     0.0000    0.0000    0.0000       200
#
#     accuracy                         0.5000       800
#    macro avg     0.1667    0.3333    0.2222       800
# weighted avg     0.2500    0.5000    0.3333       800

# %% [markdown]
# # MultinomialNB

# %%
mg=MultinomialNB()
mg.fit(x_train,y_train)
predmg=mg.predict(x_test)
print("Accuracy score =",accuracy_score(y_test,predmg))
print("Classification report=",classification_report(y_test,predmg))
print("Confusion matrix=",confusion_matrix(y_test,predmg))
# Out:
# Accuracy score = 0.5
# Classification report=               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00       200
#            4       0.50      1.00      0.67       400
#            5       0.00      0.00      0.00       200
#
#     accuracy                           0.50       800
#    macro avg       0.17      0.33      0.22       800
# weighted avg       0.25      0.50      0.33       800
#
# Confusion matrix= [[  0 200   0]
#  [  0 400   0]
#  [  0 200   0]]

# %%
clf_NB = MultinomialNB()
clf_NB.fit(x_train, y_train)
print( classification_report(y_test, clf_NB.predict(x_test), digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            3     0.0000    0.0000    0.0000       200
#            4     0.5000    1.0000    0.6667       400
#            5     0.0000    0.0000    0.0000       200
#
#     accuracy                         0.5000       800
#    macro avg     0.1667    0.3333    0.2222       800
# weighted avg     0.2500    0.5000    0.3333       800

# %%
sg=SGDClassifier()
sg.fit(x_train,y_train)
predsg=sg.predict(x_test)
print("Accuarcy_score=",accuracy_score(y_test,predsg))
print("Classification_report=",classification_report(y_test,predsg))
print("Confusion_matrix=",confusion_matrix(y_test,predsg))
# Out:
# Accuarcy_score= 0.43625
# Classification_report=               precision    recall  f1-score   support
#
#            3       0.26      0.12      0.16       200
#            4       0.50      0.74      0.60       400
#            5       0.24      0.14      0.17       200
#
#     accuracy                           0.44       800
#    macro avg       0.33      0.33      0.31       800
# weighted avg       0.38      0.44      0.38       800
#
# Confusion_matrix= [[ 24 150  26]
#  [ 44 298  58]
#  [ 25 148  27]]

# %%
clf_SGD = SGDClassifier(random_state=22)
clf_SGD.fit(x_train, y_train)
print( classification_report(y_test, clf_SGD.predict(x_test), digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            3     0.0000    0.0000    0.0000       200
#            4     0.5000    1.0000    0.6667       400
#            5     0.0000    0.0000    0.0000       200
#
#     accuracy                         0.5000       800
#    macro avg     0.1667    0.3333    0.2222       800
# weighted avg     0.2500    0.5000    0.3333       800

# %% [markdown]
# The alpha paramter determines what value we give the when we see a feature that we haven’t encountered in the testing data. We can’t use 0 because MultinomialNB multiplies these probabilities together and our whole prediction becomes 0. For example, if we find a 5-star review with a single word that we’ve never seen in a 5-star review before we don’t want our prediction to be 0.

# %%
parameters = { 'alpha': [0.1, 0.25, 0.5, 0.75, 1.0, 1.25, 1.5, 1.75, 2] }
clf_NB_refined = GridSearchCV(MultinomialNB(), parameters)
clf_NB_refined.fit(x_train, y_train)
# Out:
# GridSearchCV(estimator=MultinomialNB(),
#              param_grid={'alpha': [0.1, 0.25, 0.5, 0.75, 1.0, 1.25, 1.5, 1.75,
#                                    2]})

# %%
# Print out the parameters GridSearchCV decided on.
clf_NB_refined.best_params_
# Out:
# {'alpha': 0.25}

# %% [markdown]
# The SGDClassifier guide on sklearn’s site gives some reasonable ranges to search over for alpha and n_iter. It recommends the range 10.0**-np.arange(1,7) for alpha and np.ceil(10**6 / n) (n is the size of the training set) as a first guess for n_iter. Since our training size has 289,645 rows, it recommends a n_iter of 3, so we are going to try a couple of values around 3. For penalty, we are just going to try every possible value. Finally, we are going to try three loss functions: hinge (linear SVM), log (logistic regression), perceptron (perceptron algorithm)

# %%
clf_SGD_refined = SGDClassifier(loss='hinge',penalty='l2',max_iter=5)
clf_SGD_refined.fit(x_train, y_train)
# Out:
# SGDClassifier(max_iter=5)

# %%
clf_NB_refined.best_params_
# Out:
# {'alpha': 0.25}

# %% [markdown]
# # Compare model

# %%
print("\nAccuracy: ")
print( "LogisticRegression: " + repr(accuracy_score(y_test, clf_benchmark.predict(x_test))) )
print( "MultinomialNB:      " + repr(accuracy_score(y_test, clf_NB_refined.predict(x_test))) )
print( "SGDClassifier:      " + repr(accuracy_score(y_test, clf_SGD_refined.predict(x_test))) )

print("\nclassification reports: ")
print( "LogisticRegression: " )
print( classification_report(y_test, clf_benchmark.predict(x_test), digits=4))
print( "MultinomialNB: " ) 
print( classification_report(y_test, clf_NB_refined.predict(x_test), digits=4))
print( "SGDClassifier: " ) 
print( classification_report(y_test, clf_SGD_refined.predict(x_test), digits=4))
# Out:
# Accuracy:
# LogisticRegression: 0.5
# MultinomialNB:      0.5
# SGDClassifier:      0.40125
#
# classification reports:
# LogisticRegression:
#               precision    recall  f1-score   support
#
#            3     0.0000    0.0000    0.0000       200
#            4     0.5000    1.0000    0.6667       400
#            5     0.0000    0.0000    0.0000       200
#
#     accuracy                         0.5000       800
#    macro avg     0.1667    0.3333    0.2222       800
# weighted avg     0.2500    0.5000    0.3333       800
#
# MultinomialNB:
#               precision    recall  f1-score   support
#
#            3     0.0000    0.0000    0.0000       200
#            4     0.5000    1.0000    0.6667       400
#            5     0.0000    0.0000    0.0000       200
#
#     accuracy                         0.5000       800
#    macro avg     0.1667    0.3333    0.2222       800
# weighted avg     0.2500    0.5000    0.3333       800
#
# SGDClassifier:
# ...

# %%
# A function to help create confusion matrices.
# http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html
def plot_confusion_matrix(cm, title='Confusion matrix', cmap=plt.cm.Blues):
    plt.figure( figsize=(9,4), facecolor='white')
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(set(rating)))
    plt.xticks(tick_marks, set(rating), rotation=45)
    plt.yticks(tick_marks, set(rating))
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
# A function to create and print confusion matrix.
def create_and_print_confusion_matrix(y_test, predicted, title):
    cm = confusion_matrix(y_test, predicted)
    np.set_printoptions(precision=2)
    plt.figure()
    plot_confusion_matrix(cm, title) 
    plt.show()

# %%
# Create SGDClassifier confusion matrix.
create_and_print_confusion_matrix(y_test, clf_SGD_refined.predict(x_test), "SGDClassifier")

# %%
#creating sence of loud word
word_string=' '.join('Reviews')
wordcloud=WordCloud(stopwords=STOPWORDS,
                      background_color='white',
                      max_words=100,
                      width=700,
                      height=500
                     ).generate(word_string)

plt.figure( figsize=(10,10), facecolor='r')
plt.imshow(wordcloud)
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()
